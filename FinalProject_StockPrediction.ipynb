# %% [markdown]
# <a href="https://colab.research.google.com/github/DonSaca/stock-price-movement-predictor/blob/main/FinalProject_StockPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STOCK PRICE MOVEMENT PREDICTOR

# %%
# !pip install yfinance xgboost scikit-learn pandas matplotlib seaborn

# %% [markdown]
# Test importing

# %%
import yfinance as yf
import xgboost
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries loaded successfully.")
# Out:
# Libraries loaded successfully.

# %%
# Download NVDA historical data
df = yf.download("NVDA", start="2022-01-01", end="2024-12-31")
df.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           NVDA       NVDA       NVDA       NVDA       NVDA
# Date
# 2022-01-03  30.068224  30.657190  29.732812  29.762760  391547000
# 2022-01-04  29.238678  30.414613  28.299327  30.223948  527154000
# 2022-01-05  27.555634  29.364459  27.484759  28.898276  498064000
# 2022-01-06  28.128628  28.388172  27.017579  27.591570  454186000
# 2022-01-07  27.199253  28.372195  27.009585  28.091687  409939000
